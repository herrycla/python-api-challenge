# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
response=requests.get(query_url+"London")
results = response.json()
print(results)
# Out:
# {'coord': {'lon': -0.09, 'lat': 51.51}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 7.05, 'feels_like': 1.19, 'temp_min': 5.56, 'temp_max': 8.33, 'pressure': 1005, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 6.2, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1582586884, 'sys': {'type': 1, 'id': 1502, 'country': 'GB', 'sunrise': 1582527465, 'sunset': 1582565396}, 'timezone': 0, 'id': 2643741, 'name': 'City of London', 'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | mount gambier
# Processing Record 4 of Set 1 | gweta
# Processing Record 5 of Set 1 | broome
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | kovdor
# Processing Record 9 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | lagoa
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | illoqqortoormiut
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | maholi
# Processing Record 21 of Set 1 | ancud
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | belyy yar
# Processing Record 24 of Set 1 | tadine
# Processing Record 25 of Set 1 | namanga
# Processing Record 26 of Set 1 | cabo san lucas
# Processing Record 27 of Set 1 | norrtalje
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | timizart
# Processing Record 30 of Set 1 | sidi ali
# Processing Record 31 of Set 1 | xining
# Processing Record 32 of Set 1 | sao felix do xingu
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | vestmannaeyjar
# Processing Record 40 of Set 1 | skjervoy
# Processing Record 41 of Set 1 | geraldton
# Processing Record 42 of Set 1 | pandan
# Processing Record 43 of Set 1 | noyabrsk
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | ordzhonikidze
# Processing Record 47 of Set 1 | lorengau
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | yining
# Processing Record 50 of Set 1 | ordu
# Processing Record 0 of Set 2 | khatanga
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | caceres
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 2 | clyde river
# Processing Record 6 of Set 2 | jishou
# Processing Record 7 of Set 2 | hwange
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | leshukonskoye
# Processing Record 10 of Set 2 | tsihombe
# Processing Record 11 of Set 2 | longyearbyen
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | kashi
# Processing Record 14 of Set 2 | vilyuysk
# Processing Record 15 of Set 2 | san nicolas
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | santo domingo
# Processing Record 18 of Set 2 | oda
# Processing Record 19 of Set 2 | comodoro rivadavia
# Processing Record 20 of Set 2 | santa maria
# Processing Record 21 of Set 2 | nouadhibou
# Processing Record 22 of Set 2 | edd
# Processing Record 23 of Set 2 | emerald
# Processing Record 24 of Set 2 | havelock
# Processing Record 25 of Set 2 | katherine
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | nioro
# Processing Record 28 of Set 2 | port blair
# Processing Record 29 of Set 2 | vila velha
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | monthey
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | sakete
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 2 | san pedro
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | haverfordwest
# Processing Record 41 of Set 2 | chilca
# Processing Record 42 of Set 2 | juneau
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | vanavara
# Processing Record 46 of Set 2 | kutum
# Processing Record 47 of Set 2 | lundazi
# Processing Record 48 of Set 2 | seoul
# Processing Record 49 of Set 2 | taksimo
# Processing Record 0 of Set 3 | hithadhoo
# Processing Record 1 of Set 3 | sao filipe
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | tautira
# Processing Record 4 of Set 3 | provideniya
# Processing Record 5 of Set 3 | shuangcheng
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | aksu
# Processing Record 8 of Set 3 | daru
# Processing Record 9 of Set 3 | ahipara
# Processing Record 10 of Set 3 | marystown
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | tigzirt
# Processing Record 13 of Set 3 | taolanaro
# Processing Record 14 of Set 3 | mayskiy
# Processing Record 15 of Set 3 | lethem
# Processing Record 16 of Set 3 | rawson
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | matara
# Processing Record 19 of Set 3 | port-cartier
# Processing Record 20 of Set 3 | ostrovnoy
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | taltal
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | soyo
# Processing Record 25 of Set 3 | cockburn town
# Processing Record 26 of Set 3 | agadir
# Processing Record 27 of Set 3 | phan thiet
# Processing Record 28 of Set 3 | marawi
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | virginia beach
# Processing Record 31 of Set 3 | angoram
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | paramonga
# Processing Record 36 of Set 3 | honningsvag
# Processing Record 37 of Set 3 | pulandian
# Processing Record 38 of Set 3 | egvekinot
# Processing Record 39 of Set 3 | concordia
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | ciudad bolivar
# Processing Record 42 of Set 3 | cayenne
# Processing Record 43 of Set 3 | palabuhanratu
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | fuling
# Processing Record 46 of Set 3 | asau
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | cidreira
# Processing Record 0 of Set 4 | victoria
# Processing Record 1 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 4 | yanam
# Processing Record 3 of Set 4 | muroto
# Processing Record 4 of Set 4 | klaksvik
# Processing Record 5 of Set 4 | huarmey
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | torbay
# Processing Record 8 of Set 4 | kenai
# Processing Record 9 of Set 4 | acapulco
# Processing Record 10 of Set 4 | high level
# Processing Record 11 of Set 4 | barra
# Processing Record 12 of Set 4 | leningradskiy
# Processing Record 13 of Set 4 | rabo de peixe
# Processing Record 14 of Set 4 | tuatapere
# Processing Record 15 of Set 4 | goderich
# Processing Record 16 of Set 4 | magway
# Processing Record 17 of Set 4 | saldanha
# Processing Record 18 of Set 4 | coihaique
# Processing Record 19 of Set 4 | miranda
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | fiumicino
# Processing Record 22 of Set 4 | mildura
# Processing Record 23 of Set 4 | payson
# Processing Record 24 of Set 4 | broken hill
# Processing Record 25 of Set 4 | halifax
# Processing Record 26 of Set 4 | narimanov
# Processing Record 27 of Set 4 | pevek
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | araouane
# Processing Record 30 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 4 | sumbawa
# Processing Record 32 of Set 4 | iqaluit
# Processing Record 33 of Set 4 | fairbanks
# Processing Record 34 of Set 4 | pochutla
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | bandarbeyla
# Processing Record 37 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | port lincoln
# Processing Record 40 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 4 | moose factory
# Processing Record 42 of Set 4 | havre-saint-pierre
# Processing Record 43 of Set 4 | paamiut
# Processing Record 44 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 4 | higuey
# Processing Record 46 of Set 4 | yatou
# Processing Record 47 of Set 4 | buala
# Processing Record 48 of Set 4 | deputatskiy
# Processing Record 49 of Set 4 | sovetskiy
# Processing Record 0 of Set 5 | karratha
# Processing Record 1 of Set 5 | el alto
# Processing Record 2 of Set 5 | gukovo
# Processing Record 3 of Set 5 | faanui
# Processing Record 4 of Set 5 | banda aceh
# Processing Record 5 of Set 5 | atambua
# Processing Record 6 of Set 5 | port hedland
# Processing Record 7 of Set 5 | puerto ayora
# Processing Record 8 of Set 5 | sorvag
# Processing Record 9 of Set 5 | grand gaube
# Processing Record 10 of Set 5 | ulaangom
# Processing Record 11 of Set 5 | sao joao da barra
# Processing Record 12 of Set 5 | manokwari
# Processing Record 13 of Set 5 | iaciara
# Processing Record 14 of Set 5 | bloomfield
# Processing Record 15 of Set 5 | sistranda
# Processing Record 16 of Set 5 | chase
# Processing Record 17 of Set 5 | bubaque
# Processing Record 18 of Set 5 | rocha
# Processing Record 19 of Set 5 | ribeira grande
# Processing Record 20 of Set 5 | samarai
# Processing Record 21 of Set 5 | shebalino
# Processing Record 22 of Set 5 | padang
# Processing Record 23 of Set 5 | requena
# Processing Record 24 of Set 5 | pontes e lacerda
# Processing Record 25 of Set 5 | raymond
# Processing Record 26 of Set 5 | vuktyl
# Processing Record 27 of Set 5 | dolneni
# Processing Record 28 of Set 5 | balabac
# Processing Record 29 of Set 5 | vannes
# Processing Record 30 of Set 5 | den helder
# Processing Record 31 of Set 5 | pekin
# Processing Record 32 of Set 5 | pipri
# Processing Record 33 of Set 5 | chimbote
# Processing Record 34 of Set 5 | bambous virieux
# Processing Record 35 of Set 5 | kaka
# Processing Record 36 of Set 5 | esmeraldas
# Processing Record 37 of Set 5 | alofi
# Processing Record 38 of Set 5 | plettenberg bay
# Processing Record 39 of Set 5 | verkhnyaya inta
# Processing Record 40 of Set 5 | sorland
# Processing Record 41 of Set 5 | marsa matruh
# Processing Record 42 of Set 5 | garowe
# Processing Record 43 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 5 | ariquemes
# Processing Record 45 of Set 5 | roanoke rapids
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | ilulissat
# Processing Record 48 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 5 | road town
# Processing Record 0 of Set 6 | maxixe
# Processing Record 1 of Set 6 | casper
# Processing Record 2 of Set 6 | general roca
# Processing Record 3 of Set 6 | matadi
# Processing Record 4 of Set 6 | castro
# Processing Record 5 of Set 6 | puerto ayacucho
# Processing Record 6 of Set 6 | magnitogorsk
# Processing Record 7 of Set 6 | hasaki
# Processing Record 8 of Set 6 | aklavik
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | limbe
# Processing Record 11 of Set 6 | sambava
# Processing Record 12 of Set 6 | tabou
# Processing Record 13 of Set 6 | sarankhola
# Processing Record 14 of Set 6 | winslow
# Processing Record 15 of Set 6 | saint-denis
# Processing Record 16 of Set 6 | georgetown
# Processing Record 17 of Set 6 | saint-augustin
# Processing Record 18 of Set 6 | lokosovo
# Processing Record 19 of Set 6 | dzhusaly
# Processing Record 20 of Set 6 | carolina
# Processing Record 21 of Set 6 | port pirie
# Processing Record 22 of Set 6 | velingara
# Processing Record 23 of Set 6 | dunedin
# Processing Record 24 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 6 | saint anthony
# Processing Record 26 of Set 6 | tevaitoa
# Processing Record 27 of Set 6 | ugoofaaru
# Processing Record 28 of Set 6 | abu dhabi
# Processing Record 29 of Set 6 | atar
# Processing Record 30 of Set 6 | atuona
# Processing Record 31 of Set 6 | carbonia
# Processing Record 32 of Set 6 | mao
# Processing Record 33 of Set 6 | lebu
# Processing Record 34 of Set 6 | kaniv
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | sitka
# Processing Record 37 of Set 6 | isangel
# Processing Record 38 of Set 6 | aykhal
# Processing Record 39 of Set 6 | luderitz
# Processing Record 40 of Set 6 | prieska
# Processing Record 41 of Set 6 | bonavista
# Processing Record 42 of Set 6 | san patricio
# Processing Record 43 of Set 6 | srednekolymsk
# Processing Record 44 of Set 6 | san lorenzo
# Processing Record 45 of Set 6 | salalah
# Processing Record 46 of Set 6 | rio bravo
# Processing Record 47 of Set 6 | springville
# Processing Record 48 of Set 6 | tailai
# Processing Record 49 of Set 6 | constitucion
# Processing Record 0 of Set 7 | igunga
# Processing Record 1 of Set 7 | tuktoyaktuk
# Processing Record 2 of Set 7 | novikovo
# Processing Record 3 of Set 7 | invermere
# Processing Record 4 of Set 7 | archidona
# Processing Record 5 of Set 7 | san cristobal
# Processing Record 6 of Set 7 | upernavik
# Processing Record 7 of Set 7 | prosyana
# Processing Record 8 of Set 7 | gulu
# Processing Record 9 of Set 7 | beringovskiy
# Processing Record 10 of Set 7 | talas
# Processing Record 11 of Set 7 | kahului
# Processing Record 12 of Set 7 | antalaha
# Processing Record 13 of Set 7 | haines junction
# Processing Record 14 of Set 7 | tuggurt
# Processing Record 15 of Set 7 | vila franca do campo
# Processing Record 16 of Set 7 | tome
# Processing Record 17 of Set 7 | wang saphung
# Processing Record 18 of Set 7 | urbino
# Processing Record 19 of Set 7 | ixtapa
# Processing Record 20 of Set 7 | derzhavinsk
# Processing Record 21 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 7 | ilo
# Processing Record 23 of Set 7 | ormara
# Processing Record 24 of Set 7 | mount isa
# Processing Record 25 of Set 7 | visby
# Processing Record 26 of Set 7 | ayaviri
# Processing Record 27 of Set 7 | henties bay
# Processing Record 28 of Set 7 | meulaboh
# Processing Record 29 of Set 7 | tyup
# Processing Record 30 of Set 7 | airai
# Processing Record 31 of Set 7 | guerrero
# Processing Record 32 of Set 7 | namatanai
# Processing Record 33 of Set 7 | krasnoselkup
# Processing Record 34 of Set 7 | la antigua
# Processing Record 35 of Set 7 | san luis
# Processing Record 36 of Set 7 | sept-iles
# Processing Record 37 of Set 7 | dovbysh
# Processing Record 38 of Set 7 | poum
# Processing Record 39 of Set 7 | shumikha
# Processing Record 40 of Set 7 | gemlik
# Processing Record 41 of Set 7 | abu kamal
# Processing Record 42 of Set 7 | wuwei
# Processing Record 43 of Set 7 | tir pol
# Processing Record 44 of Set 7 | purwodadi
# Processing Record 45 of Set 7 | rapid city
# Processing Record 46 of Set 7 | grand river south east
# Processing Record 47 of Set 7 | marcona
# Processing Record 48 of Set 7 | clearlake
# Processing Record 49 of Set 7 | stromness
# Processing Record 0 of Set 8 | tolmin
# Processing Record 1 of Set 8 | saint george
# Processing Record 2 of Set 8 | the pas
# Processing Record 3 of Set 8 | dwarka
# Processing Record 4 of Set 8 | lompoc
# Processing Record 5 of Set 8 | kamenka
# Processing Record 6 of Set 8 | lucapa
# Processing Record 7 of Set 8 | ujszasz
# Processing Record 8 of Set 8 | riyadh
# Processing Record 9 of Set 8 | singaraja
# Processing Record 10 of Set 8 | marshall
# Processing Record 11 of Set 8 | morondava
# Processing Record 12 of Set 8 | kurchum
# Processing Record 13 of Set 8 | mayumba
# Processing Record 14 of Set 8 | westport
# Processing Record 15 of Set 8 | kapit
# Processing Record 16 of Set 8 | los llanos de aridane
# Processing Record 17 of Set 8 | west wendover
# Processing Record 18 of Set 8 | yar-sale
# Processing Record 19 of Set 8 | kurilsk
# Processing Record 20 of Set 8 | bonthe
# Processing Record 21 of Set 8 | point pleasant
# Processing Record 22 of Set 8 | storslett
# Processing Record 23 of Set 8 | kavaratti
# Processing Record 24 of Set 8 | nhulunbuy
# Processing Record 25 of Set 8 | manati
# Processing Record 26 of Set 8 | farrukhnagar
# Processing Record 27 of Set 8 | lazaro cardenas
# Processing Record 28 of Set 8 | freeport
# Processing Record 29 of Set 8 | yulara
# Processing Record 30 of Set 8 | bud
# Processing Record 31 of Set 8 | turbat
# Processing Record 32 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 8 | togur
# Processing Record 34 of Set 8 | margate
# Processing Record 35 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 8 | bacong
# Processing Record 37 of Set 8 | vardo
# Processing Record 38 of Set 8 | bethanien
# Processing Record 39 of Set 8 | karatau
# Processing Record 40 of Set 8 | pimentel
# Processing Record 41 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 8 | ati
# Processing Record 43 of Set 8 | ambodifototra
# Processing Record 44 of Set 8 | inhambane
# Processing Record 45 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 8 | daltenganj
# Processing Record 47 of Set 8 | miles city
# Processing Record 48 of Set 8 | sedlcany
# Processing Record 49 of Set 8 | sergeyevka
# Processing Record 0 of Set 9 | coachella
# Processing Record 1 of Set 9 | husavik
# Processing Record 2 of Set 9 | szczecinek
# Processing Record 3 of Set 9 | fernie
# Processing Record 4 of Set 9 | chadiza
# Processing Record 5 of Set 9 | palauig
# Processing Record 6 of Set 9 | hobyo
# Processing Record 7 of Set 9 | danielskuil
# Processing Record 8 of Set 9 | okhotsk
# Processing Record 9 of Set 9 | oistins
# Processing Record 10 of Set 9 | bethel
# Processing Record 11 of Set 9 | umm kaddadah
# Processing Record 12 of Set 9 | letka
# Processing Record 13 of Set 9 | eureka
# Processing Record 14 of Set 9 | vitim
# Processing Record 15 of Set 9 | olafsvik
# Processing Record 16 of Set 9 | kapoeta
# Processing Record 17 of Set 9 | umm lajj
# Processing Record 18 of Set 9 | ambon
# Processing Record 19 of Set 9 | madimba
# Processing Record 20 of Set 9 | axim
# Processing Record 21 of Set 9 | sharjah
# Processing Record 22 of Set 9 | narsaq
# Processing Record 23 of Set 9 | brae
# Processing Record 24 of Set 9 | najran
# Processing Record 25 of Set 9 | camopi
# Processing Record 26 of Set 9 | kavieng
# Processing Record 27 of Set 9 | vostok
# Processing Record 28 of Set 9 | erenhot
# Processing Record 29 of Set 9 | yermakovskoye
# Processing Record 30 of Set 9 | ust-tsilma
# Processing Record 31 of Set 9 | galle
# Processing Record 32 of Set 9 | chokurdakh
# Processing Record 33 of Set 9 | hailey
# Processing Record 34 of Set 9 | maragogi
# Processing Record 35 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 9 | fairmont
# Processing Record 37 of Set 9 | braslav
# Processing Record 38 of Set 9 | adet
# Processing Record 39 of Set 9 | marsabit
# Processing Record 40 of Set 9 | chinhoyi
# Processing Record 41 of Set 9 | kollam
# Processing Record 42 of Set 9 | marzuq
# Processing Record 43 of Set 9 | mamakan
# Processing Record 44 of Set 9 | consolacion del sur
# Processing Record 45 of Set 9 | teguldet
# Processing Record 46 of Set 9 | cherkasskoye
# Processing Record 47 of Set 9 | lubao
# Processing Record 48 of Set 9 | awjilah
# Processing Record 49 of Set 9 | sabha
# Processing Record 0 of Set 10 | sangre grande
# Processing Record 1 of Set 10 | kupang
# Processing Record 2 of Set 10 | caravelas
# Processing Record 3 of Set 10 | ola
# Processing Record 4 of Set 10 | pascagoula
# Processing Record 5 of Set 10 | bac lieu
# Processing Record 6 of Set 10 | tshikapa
# Processing Record 7 of Set 10 | brawley
# Processing Record 8 of Set 10 | kisangani
# Processing Record 9 of Set 10 | coquimbo
# Processing Record 10 of Set 10 | pioner
# Processing Record 11 of Set 10 | verkhoyansk
# Processing Record 12 of Set 10 | sao joao da boa vista
# Processing Record 13 of Set 10 | catuday
# Processing Record 14 of Set 10 | faya
# Processing Record 15 of Set 10 | mnogovershinnyy
# Processing Record 16 of Set 10 | hualmay
# Processing Record 17 of Set 10 | mahajanga
# Processing Record 18 of Set 10 | srikakulam
# Processing Record 19 of Set 10 | pombia
# Processing Record 20 of Set 10 | kargasok
# Processing Record 21 of Set 10 | lakatoro
# Processing Record 22 of Set 10 | ust-ilimsk
# Processing Record 23 of Set 10 | melnikovo
# Processing Record 24 of Set 10 | naze
# Processing Record 25 of Set 10 | bontang
# Processing Record 26 of Set 10 | guanare
# Processing Record 27 of Set 10 | puerto madryn
# Processing Record 28 of Set 10 | tura
# Processing Record 29 of Set 10 | caarapo
# Processing Record 30 of Set 10 | palana
# Processing Record 31 of Set 10 | luganville
# Processing Record 32 of Set 10 | aksehir
# Processing Record 33 of Set 10 | khorramabad
# Processing Record 34 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 35 of Set 10 | antsohihy
# Processing Record 36 of Set 10 | east london
# Processing Record 37 of Set 10 | carmen
# Processing Record 38 of Set 10 | college
# Processing Record 39 of Set 10 | alice town
# Processing Record 40 of Set 10 | chapais
# Processing Record 41 of Set 10 | mayo
# Processing Record 42 of Set 10 | te anau
# Processing Record 43 of Set 10 | kidodi
# Processing Record 44 of Set 10 | xapuri
# Processing Record 45 of Set 10 | kieta
# Processing Record 46 of Set 10 | tooele
# Processing Record 47 of Set 10 | kulebaki
# Processing Record 48 of Set 10 | diapaga
# Processing Record 49 of Set 10 | ossora
# Processing Record 0 of Set 11 | gornopravdinsk
# Processing Record 1 of Set 11 | santa cruz
# Processing Record 2 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 11 | hirara
# Processing Record 4 of Set 11 | matsanga
# City not found. Skipping...
# Processing Record 5 of Set 11 | kloulklubed
# Processing Record 6 of Set 11 | grojec
# Processing Record 7 of Set 11 | urumqi
# Processing Record 8 of Set 11 | darfo
# Processing Record 9 of Set 11 | ahuimanu
# Processing Record 10 of Set 11 | portland
# Processing Record 11 of Set 11 | monrovia
# Processing Record 12 of Set 11 | san buenaventura
# Processing Record 13 of Set 11 | saint-joseph
# Processing Record 14 of Set 11 | north myrtle beach
# Processing Record 15 of Set 11 | erzin
# Processing Record 16 of Set 11 | artyom
# Processing Record 17 of Set 11 | klyuchi
# Processing Record 18 of Set 11 | barbastro
# Processing Record 19 of Set 11 | carutapera
# Processing Record 20 of Set 11 | asuncion
# Processing Record 21 of Set 11 | montego bay
# Processing Record 22 of Set 11 | shingu
# Processing Record 23 of Set 11 | la ronge
# Processing Record 24 of Set 11 | haimen
# Processing Record 25 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 26 of Set 11 | wajir
# Processing Record 27 of Set 11 | odweyne
# Processing Record 28 of Set 11 | byron bay
# Processing Record 29 of Set 11 | myre
# Processing Record 30 of Set 11 | kazalinsk
# Processing Record 31 of Set 11 | launceston
# Processing Record 32 of Set 11 | minab
# Processing Record 33 of Set 11 | midland
# Processing Record 34 of Set 11 | necochea
# Processing Record 35 of Set 11 | batangafo
# Processing Record 36 of Set 11 | coihueco
# Processing Record 37 of Set 11 | gamba
# Processing Record 38 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 39 of Set 11 | mogadishu
# Processing Record 40 of Set 11 | wenling
# Processing Record 41 of Set 11 | chatellerault
# Processing Record 42 of Set 11 | fort nelson
# Processing Record 43 of Set 11 | mitsamiouli
# Processing Record 44 of Set 11 | andevoranto
# Processing Record 45 of Set 11 | asfi
# Processing Record 46 of Set 11 | jiddah
# Processing Record 47 of Set 11 | olinda
# Processing Record 48 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 11 | boende
# Processing Record 0 of Set 12 | candido mendes
# Processing Record 1 of Set 12 | mason city
# Processing Record 2 of Set 12 | cagliliog
# Processing Record 3 of Set 12 | san isidro
# Processing Record 4 of Set 12 | cocorit
# Processing Record 5 of Set 12 | bakel
# Processing Record 6 of Set 12 | sao gabriel da cachoeira
# Processing Record 7 of Set 12 | avera
# Processing Record 8 of Set 12 | jizan
# Processing Record 9 of Set 12 | turukhansk
# Processing Record 10 of Set 12 | richards bay
# Processing Record 11 of Set 12 | dhali
# Processing Record 12 of Set 12 | sterling
# Processing Record 13 of Set 12 | ibb
# Processing Record 14 of Set 12 | port said
# Processing Record 15 of Set 12 | fayaoue
# Processing Record 16 of Set 12 | gatton
# Processing Record 17 of Set 12 | taoudenni
# Processing Record 18 of Set 12 | ust-kuyga
# Processing Record 19 of Set 12 | viedma
# Processing Record 20 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 12 | buqayq
# Processing Record 22 of Set 12 | saint-francois
# Processing Record 23 of Set 12 | muncar
# Processing Record 24 of Set 12 | litovko
# Processing Record 25 of Set 12 | qasigiannguit
# Processing Record 26 of Set 12 | rivera
# Processing Record 27 of Set 12 | foshan
# Processing Record 28 of Set 12 | spas-klepiki
# Processing Record 29 of Set 12 | antigonish
# Processing Record 30 of Set 12 | tateyama
# Processing Record 31 of Set 12 | touros
# Processing Record 32 of Set 12 | chicama
# Processing Record 33 of Set 12 | kirakira
# Processing Record 34 of Set 12 | brewster
# Processing Record 35 of Set 12 | marsh harbour
# Processing Record 36 of Set 12 | upington
# Processing Record 37 of Set 12 | shitkino
# Processing Record 38 of Set 12 | iskateley
# Processing Record 39 of Set 12 | vittoria
# Processing Record 40 of Set 12 | labuhan
# Processing Record 41 of Set 12 | sibolga
# Processing Record 42 of Set 12 | loralai
# Processing Record 43 of Set 12 | tarudant
# Processing Record 44 of Set 12 | hammerfest
# Processing Record 45 of Set 12 | souillac
# Processing Record 46 of Set 12 | lewisporte
# Processing Record 47 of Set 12 | pemangkat
# Processing Record 48 of Set 12 | berea
# Processing Record 49 of Set 12 | moussoro
# Processing Record 0 of Set 13 | mangan
# Processing Record 1 of Set 13 | krapivinskiy
# Processing Record 2 of Set 13 | palmerston
# Processing Record 3 of Set 13 | avallon
# Processing Record 4 of Set 13 | sur
# Processing Record 5 of Set 13 | nemuro
# Processing Record 6 of Set 13 | pauini
# Processing Record 7 of Set 13 | dubovskoye
# Processing Record 8 of Set 13 | krasnoarmeyskiy
# Processing Record 9 of Set 13 | dingle
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-6c8fc7b93d75> in <module>
#      10
#      11 # Export the City_Data into a csv
# ---> 12 city_data_pd.to_csv(output_data_file, index_label="City_ID")
#      13
#      14 # Show Record Count
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/cities.csv'

# %%
# Display the City Data Frame
city_data_pd.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
 # Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-30,40))

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-30,150))

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-30,30))
